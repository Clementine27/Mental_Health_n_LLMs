# %%
import os
cwd = os.getcwd()
new_path = os.path.dirname(cwd)
# print(os.path.dirname(cwd))

# %%
new_path
# Out:
# '/Users/ngokykhanhthu/Documents/Mental_Health_n_LLMs'

# %%
import sys 
sys.path.append(new_path)

# %%
import re 
# import requests
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np 
import os
import json
import subprocess
from datetime import datetime
from mental.config import RAW_DIR, INTERIM_DIR, PROCESSED_DIR, FINAL_DIR, FINAL_DIR_2, DATASET, DATA_KEYWORD, CHAT_GPT_QUESTION
